# %%
import pandas as pd
df_sampah = pd.read_excel('dataset_sampah.xlsx', sheet_name='data')

(df_sampah)
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      1             32    JAWA BARAT                 3201
# 1      2             32    JAWA BARAT                 3202
# 2      3             32    JAWA BARAT                 3203
# 3      4             32    JAWA BARAT                 3204
# 4      5             32    JAWA BARAT                 3205
# ..   ...            ...           ...                  ...
# 238  239             32    JAWA BARAT                 3275
# 239  240             32    JAWA BARAT                 3276
# 240  241             32    JAWA BARAT                 3277
# 241  242             32    JAWA BARAT                 3278
# 242  243             32    JAWA BARAT                 3279
#
#     nama_kabupaten_kota  jumlah_produksi_sampah        satuan  tahun
# 0       KABUPATEN BOGOR                 1511.15  TON PER HARI   2015
# 1    KABUPATEN SUKABUMI                  419.01  TON PER HARI   2015
# ...

# %%
total_2015=[]
for index, row in df_sampah.iterrows():
    if row['tahun']==2015:
        total_2015.append(row['jumlah_produksi_sampah'])

total_sampah_2015=sum(total_2015)
print(f"jumlah total sampah di tahun 2015: {total_sampah_2015}")
# Out:
# jumlah total sampah di tahun 2015: 20969.27

# %%
total_per_tahun = defaultdict(int)

for index, row in df_sampah.iterrows():
    tahun = row['tahun'] 
    total_per_tahun[tahun] += row['jumlah_produksi_sampah']

total_per_tahun = dict(total_per_tahun)

for tahun, total in total_per_tahun.items():
    print(f"Jumlah total sampah di tahun {tahun}: {total}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 total_per_tahun = defaultdict(int)
#       3 for index, row in df_sampah.iterrows():
#       4     tahun = row['tahun']
#
# NameError: name 'defaultdict' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 9
#       7     if tahun not in total_per_tahun:
#       8         total_per_tahun[kota] = 0
# ----> 9     total_per_tahun[kota] += jumlah
#      11 for kota, total in total_per_tahun.items():
#      12     print(f"Jumlah total sampah di tahun {kota}: {total}")
#
# KeyError: 'KABUPATEN BOGOR'

# %%
hasil_kota_per_tahun = {}
for index, row in df_sampah.iterrows():
    tahun = row["tahun"]
    kota = row["nama_kabupaten_kota"]
    jumlah = row["jumlah_produksi_sampah"]

    if (tahun, kota) not in hasil_kota_per_tahun:
        hasil_kota_per_tahun[(tahun, kota)] = 0
    hasil_kota_per_tahun[(tahun, kota)] += jumlah

print("Produksi sampah per Kota/Kabupaten per tahun:")
for key, value in hasil_kota_per_tahun.items():
    print(f"{key[1]} ({key[0]}): {value} ton")
# Out:
# Produksi sampah per Kota/Kabupaten per tahun:
# KABUPATEN BOGOR (2015): 1511.15 ton
# KABUPATEN SUKABUMI (2015): 419.01 ton
# KABUPATEN CIANJUR (2015): 981.41 ton
# KABUPATEN BANDUNG (2015): 1895.94 ton
# KABUPATEN GARUT (2015): 464.74 ton
# KABUPATEN TASIKMALAYA (2015): 464.52 ton
# KABUPATEN CIAMIS (2015): 260.91 ton
# KABUPATEN KUNINGAN (2015): 251.7 ton
# KABUPATEN CIREBON (2015): 465.75 ton
# KABUPATEN MAJALENGKA (2015): 254.63 ton
# KABUPATEN SUMEDANG (2015): 237.96 ton
# KABUPATEN INDRAMAYU (2015): 613.18 ton
# KABUPATEN SUBANG (2015): 487.26 ton
# KABUPATEN PURWAKARTA (2015): 308.96 ton
# KABUPATEN KARAWANG (2015): 869.86 ton
# KABUPATEN BEKASI (2015): 1228.6 ton
# KABUPATEN BANDUNG BARAT (2015): 616.08 ton
# KABUPATEN PANGANDARAN (2015): 185.83 ton
# KOTA BOGOR (2015): 991.93 ton
# KOTA SUKABUMI (2015): 309.91 ton
# KOTA BANDUNG (2015): 2448.63 ton
# KOTA CIREBON (2015): 304.15 ton
# KOTA BEKASI (2015): 2387.08 ton
# KOTA DEPOK (2015): 1844.3 ton
# ...

# %%
from collections import defaultdict

hasil_kota_per_tahun = defaultdict(int)

# Iterasi langsung pada DataFrame
for index, row in df_sampah.iterrows():
    tahun, kota, jumlah = row["tahun"], row["nama_kabupaten_kota"], row["jumlah_produksi_sampah"]
    hasil_kota_per_tahun[(tahun, kota)] += jumlah

# Tampilkan hasil
print("Produksi sampah per Kota/Kabupaten per tahun:")
for (tahun, kota), jumlah in hasil_kota_per_tahun.items():
    print(f"{kota} ({tahun}): {jumlah} ton")
# Out:
# Produksi sampah per Kota/Kabupaten per tahun:
# KABUPATEN BOGOR (2015): 1511.15 ton
# KABUPATEN SUKABUMI (2015): 419.01 ton
# KABUPATEN CIANJUR (2015): 981.41 ton
# KABUPATEN BANDUNG (2015): 1895.94 ton
# KABUPATEN GARUT (2015): 464.74 ton
# KABUPATEN TASIKMALAYA (2015): 464.52 ton
# KABUPATEN CIAMIS (2015): 260.91 ton
# KABUPATEN KUNINGAN (2015): 251.7 ton
# KABUPATEN CIREBON (2015): 465.75 ton
# KABUPATEN MAJALENGKA (2015): 254.63 ton
# KABUPATEN SUMEDANG (2015): 237.96 ton
# KABUPATEN INDRAMAYU (2015): 613.18 ton
# KABUPATEN SUBANG (2015): 487.26 ton
# KABUPATEN PURWAKARTA (2015): 308.96 ton
# KABUPATEN KARAWANG (2015): 869.86 ton
# KABUPATEN BEKASI (2015): 1228.6 ton
# KABUPATEN BANDUNG BARAT (2015): 616.08 ton
# KABUPATEN PANGANDARAN (2015): 185.83 ton
# KOTA BOGOR (2015): 991.93 ton
# KOTA SUKABUMI (2015): 309.91 ton
# KOTA BANDUNG (2015): 2448.63 ton
# KOTA CIREBON (2015): 304.15 ton
# KOTA BEKASI (2015): 2387.08 ton
# KOTA DEPOK (2015): 1844.3 ton
# ...

# %%
#nilai yang dipisahkan oleh koma
df_sampah.to_csv('sampah_kota_kabupaten.csv', index=False)
df_sampah.to_excel('sampah_kota_kabupaten', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 #nilai yang dipisahkan oleh koma
# ----> 2 df_list.to_csv('coba.csv', index=False)
#
# NameError: name 'df_list' is not defined
